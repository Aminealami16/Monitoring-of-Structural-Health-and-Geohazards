# %%
from RunOptim import RunOptim

# %%
RunOptim()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.344605
#          Iterations: 30
#          Function evaluations: 59
# The optimal value of parameter 1 is: E-Modulus Columns = 2.8986663818359375
# The optimal value of parameter 2 is: E-Modulus Floor Group I = 5000.0
# (np.float64(2.8986663818359375), np.float64(5000.0))
