# %%
from RunOptim import RunOptim

# %%
RunOptim()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.211863
#          Iterations: 10
#          Function evaluations: 19
# The optimal value of parameter 1 is: E-Modulus Columns = 49000000000.0
# The optimal value of parameter 2 is: E-Modulus Floor Group I = 49000000000.0
# (np.float64(49000000000.0), np.float64(49000000000.0))
