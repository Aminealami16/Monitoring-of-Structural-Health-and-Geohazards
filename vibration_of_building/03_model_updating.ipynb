# %%
from RunOptim import RunOptim

# %%
RunOptim()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.502136
#          Iterations: 15
#          Function evaluations: 30
# The optimal value of parameter 1 is: k bottom = 29.5
# The optimal value of parameter 2 is: mass floor 2 = 9500.0
# (np.float64(29.5), np.float64(9500.0))
