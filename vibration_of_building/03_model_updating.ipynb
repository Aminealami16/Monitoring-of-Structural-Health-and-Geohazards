# %%
from RunOptim import RunOptim

# %%
RunOptim()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.013843
#          Iterations: 48
#          Function evaluations: 89
# The optimal value of parameter 1 is: k_bot = 4.495030056522714
# The optimal value of parameter 2 is: mass_floor_2 = 1029.666189448553
# (np.float64(4.495030056522714), np.float64(1029.666189448553))
