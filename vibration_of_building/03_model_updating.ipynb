# %%
from RunOptim import RunOptim

# %%
RunOptim()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.013843
#          Iterations: 34
#          Function evaluations: 65
# The optimal value of parameter 1 is: k_bot = 4.493741979385506
# The optimal value of parameter 2 is: mass_floor_2 = 1029.7554159347812
# (np.float64(4.493741979385506), np.float64(1029.7554159347812))
